-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %%
--Module 1 
--Demo 1
--Connect to the database

PRINT 'Hello, world!';

SELECT 'Hello, Coder Girls!';

-- %%
--This is a comment
/*
This is a multi-line
comment
*/

--Switch to query window to run this block
--How to see tables
--Right-click and select 1000
--Select the statement you want to run

SELECT 'this is statment 1';

PRINT 'this is statement 2';

GO

PRINT 'this is a different batch';

USE WideWorldImporters;
GO
USE AdventureWorks2019;
